# %%
import matplotlib.pyplot as plt
import csv
import numpy as np


data_C1_15  = np.genfromtxt("./out_C_v1_15.txt", delimiter = ',', comments='#')
data_C1_30 = np.genfromtxt("./out_C_v1_30.txt", delimiter = ',', comments='#')
data_C1_60 = np.genfromtxt("./out_C_v1_60.txt", delimiter = ',', comments='#')
data_C2_1  = np.genfromtxt("./out_C_v2_1.txt", delimiter = ',', comments='#')
y=np.argsort(data_C2_1[:,0],kind='mergesort')
data_C2_1=data_C2_1[y]
data_C2_10  = np.genfromtxt("./out_C_v2_10.txt", delimiter = ',', comments='#')
y=np.argsort(data_C2_10[:,0],kind='mergesort')
data_C2_10=data_C2_10[y]
data_C2_100  = np.genfromtxt("./out_C_v2_100.txt", delimiter = ',', comments='#')
y=np.argsort(data_C2_100[:,0],kind='mergesort')
data_C2_100=data_C2_100[y]
data_C3_1  = np.genfromtxt("./out_C_v3_1.txt", delimiter = ',', comments='#')
data_C3_10 = np.genfromtxt("./out_C_v3_10.txt", delimiter = ',', comments='#')
data_C3_100 = np.genfromtxt("./out_C_v3_100.txt", delimiter = ',', comments='#')
y=np.argsort(data_C3_100[:,0],kind='mergesort')
data_C3_100=data_C3_100[y]
data_C4_1 = np.genfromtxt("./out_C_4_1.txt", delimiter = ',', comments='#')
data_C4_01 = np.genfromtxt("./out_C_4_01.txt", delimiter = ',', comments='#')
data_C4_m100 = np.genfromtxt("./out_C_4_m100v2.txt", delimiter = ',', comments='#')
data_C4_m200 = np.genfromtxt("./out_C_4_m200v2.txt", delimiter = ',', comments='#')
data_C4_m500 = np.genfromtxt("./out_C_4_m500v2.txt", delimiter = ',', comments='#')
data_C4_m1000 = np.genfromtxt("./out_C_4_m1000v2.txt", delimiter = ',', comments='#')

# %%
# plot data
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))

plt.plot(data_C1_15[:,0],  3 * data_C1_15[:,3], color = 'grey', label = '$\Delta=\pm 3\epsilon_{MC}$')
plt.plot(data_C1_15[:,0], -3 * data_C1_15[:,3], color = 'grey')
plt.scatter(data_C1_15[:,0], (data_C1_15[:,1]-data_C1_15[:,2]) , marker='x', label = '$\sigma = 0.15 $')



plt.xlabel("m", fontsize = 13)
plt.ylabel(r'$\Delta_{}$', rotation = 0, fontsize = 13)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.legend()
plt.title("Deviazione dal valore esatto", fontsize = 15)
plt.savefig('C_a1.png')
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))

plt.plot(data_C1_30[:,0],  3 * data_C1_30[:,3], color = 'grey', label = '$\Delta=\pm 3\epsilon_{MC}$')
plt.plot(data_C1_30[:,0], -3 * data_C1_30[:,3], color = 'grey')
plt.scatter(data_C1_30[:,0], data_C1_30[:,1]-data_C1_30[:,2] , marker='x', color = 'orange', label = '$\sigma = 0.30 $')



plt.xlabel("m", fontsize = 13)
plt.ylabel(r'$\Delta_{}$', rotation = 0, fontsize = 13)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.legend()
plt.title("Deviazione dal valore esatto", fontsize = 15)
plt.savefig('C_a2.png')
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))

plt.plot(data_C1_60[:,0],  3 * data_C1_60[:,3], color = 'grey', label = '$\Delta=\pm 3\epsilon_{MC}$')
plt.plot(data_C1_60[:,0], -3 * data_C1_60[:,3], color = 'grey')
plt.scatter(data_C1_60[:,0], (data_C1_60[:,1]-data_C1_60[:,2]) , marker='x', color = 'green', label = '$\sigma = 0.30 $')



plt.xlabel("m", fontsize = 13)
plt.ylabel(r'$\Delta_{}$', rotation = 0, fontsize = 13)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.legend()
plt.title("Deviazione dal valore esatto", fontsize = 15)
plt.savefig('C_a3.png')
plt.show()

# %%
# plot data
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))

plt.plot(data_C2_1[:,0],  3 * data_C2_1[:,3], color = 'grey', label = '$\Delta=\pm 3\epsilon_{MC}$')
plt.plot(data_C2_1[:,0], -3 * data_C2_1[:,3], color = 'grey')
plt.scatter(data_C2_1[:,0], (data_C2_1[:,1]-data_C2_1[:,2]) , marker='x', label = '$m = 1 $', color = 'blue')



plt.xlabel("B", fontsize = 13)
plt.ylabel(r'$\Delta$', rotation = 0, fontsize = 16)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.legend()
plt.title("Deviazione dal valore esatto", fontsize = 15)
plt.savefig('C_b0.png')
plt.show()

# %%
# plot data
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))

#plt.plot(data_C2_1[:,0],  3 * data_C2_1[:,3], color = 'grey', label = '$\Delta=\pm 3\epsilon_{MC}$')
#plt.plot(data_C2_1[:,0], -3 * data_C2_1[:,3], color = 'grey')
plt.scatter(data_C2_1[:,0], (data_C2_1[:,1]-data_C2_1[:,2])/(data_C2_1[:,3]) , marker='x', label = '$m = 1 $', color = 'blue')



plt.xlabel("B", fontsize = 13)
plt.ylabel(r'$\frac{\Delta}{\epsilon_{MC}}$', rotation = 0, fontsize = 16)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.ylim(-3,3)
plt.legend()
plt.title("Deviazione dal valore esatto", fontsize = 15)
plt.savefig('C_b1.png')
plt.show()

# %%
# plot data
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))


#plt.plot(data_C2_10[:,0],  3 * data_C2_10[:,3], color = 'grey', label = '$\Delta=\pm 3\epsilon_{MC}$')
#plt.plot(data_C2_10[:,0], -3 * data_C2_10[:,3], color = 'grey')
plt.scatter(data_C2_10[:,0], (data_C2_10[:,1]-data_C2_10[:,2])/(data_C2_10[:,3]) , marker='x', label = '$m = 10 $', color = 'orange')



plt.xlabel("B", fontsize = 13)
plt.ylabel(r'$\frac{\Delta}{\epsilon_{MC}}$', rotation = 0, fontsize = 16)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.ylim(-3,3)
plt.legend()
plt.title("Deviazione dal valore esatto", fontsize = 15)
plt.savefig('C_b2.png')
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))

#plt.plot(data_C2_100[:,0],  np.log(3 * data_C2_100[:,3]), color = 'grey', label = '$\Delta=\pm 3\epsilon_{MC}$')
#plt.plot(data_C2_100[:,0], -3 * data_C2_100[:,3], color = 'grey')
plt.scatter(data_C2_100[:,0], (data_C2_100[:,1]-data_C2_100[:,2])/(data_C2_100[:,3]) , marker='x', label = '$m = 100 $', color = 'green')



plt.xlabel("B", fontsize = 13)
plt.ylabel(r'$\frac{\Delta}{\epsilon_{MC}}$', rotation = 0, fontsize = 16)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.ylim(-3,3)
plt.legend(loc = 'upper left')
plt.title("Deviazione dal valore esatto", fontsize = 15)
plt.savefig('C_b3.png')
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))

#plt.plot(data_C2_100[:,0],  np.log(3 * data_C2_100[:,3]), color = 'grey', label = '$\Delta=\pm 3\epsilon_{MC}$')
#plt.plot(data_C2_100[:,0], -3 * data_C2_100[:,3], color = 'grey')
plt.scatter(data_C3_1[:,0], (data_C3_1[:,1]-data_C3_1[:,2])/(data_C3_1[:,3]) , marker='x', label = '$m = 1$', color = 'blue')



plt.xlabel("K", fontsize = 13)
plt.ylabel(r'$\frac{\Delta}{\epsilon_{MC}}$', rotation = 0, fontsize = 16)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.ylim(-3,3)
plt.legend()
plt.title("Deviazione dal valore esatto", fontsize = 15)
plt.savefig('C_c1.png')
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))

#plt.plot(data_C2_100[:,0],  np.log(3 * data_C2_100[:,3]), color = 'grey', label = '$\Delta=\pm 3\epsilon_{MC}$')
#plt.plot(data_C2_100[:,0], -3 * data_C2_100[:,3], color = 'grey')
plt.scatter(data_C3_10[:,0], (data_C3_10[:,1]-data_C3_10[:,2])/(data_C3_10[:,3]) , marker='x', label = '$m = 10$', color = 'orange')



plt.xlabel("K", fontsize = 13)
plt.ylabel(r'$\frac{\Delta}{\epsilon_{MC}}$', rotation = 0, fontsize = 16)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.ylim(-3,3)
plt.legend()
plt.title("Deviazione dal valore esatto", fontsize = 15)
plt.savefig('C_c2.png')
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))

#plt.plot(data_C2_100[:,0],  np.log(3 * data_C2_100[:,3]), color = 'grey', label = '$\Delta=\pm 3\epsilon_{MC}$')
#plt.plot(data_C2_100[:,0], -3 * data_C2_100[:,3], color = 'grey')
plt.scatter(data_C3_100[:,0], (data_C3_100[:,1]-data_C3_100[:,2])/(data_C3_100[:,3]) , marker='x', label = '$m = 100$', color = 'green')



plt.xlabel("K", fontsize = 13)
plt.ylabel(r'$\frac{\Delta}{\epsilon_{MC}}$', rotation = 0, fontsize = 16)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.ylim(-3,3)
plt.legend()
plt.title("Deviazione dal valore esatto", fontsize = 15)
plt.savefig('C_c3.png')
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=100, facecolor=(1, 1, 1))

#plt.plot((data_C4_01[:,0]), np.log10(abs(data_C4_01[:,2]-data_C4_01[:,1])), marker = '.', color = 'green', label = "T=1")
#plt.plot((data_C4[:,0]), (data_C4[:,1]), marker = '.', color = 'orange', label = 'montecarlo')
plt.plot((data_C4_m100[:,0]), (abs(data_C4_m100[:,1])), marker = '.', color = 'blue', label = 'm=100')
plt.plot((data_C4_m200[:,0]), (abs(data_C4_m200[:,1])), marker = '.', color = 'orange', label = 'm=200')
plt.plot((data_C4_m500[:,0]), (abs(data_C4_m500[:,1])), marker = '.', color = 'yellow', label = 'm=500')
plt.plot((data_C4_m1000[:,0]), (abs(data_C4_m1000[:,1])), marker = '.', color = 'green', label = 'm=1000')
#plt.plot((data_C4[:,0]), (np.log(data_C4[:,3])) , color = 'grey')
#plt.plot(data_C4[:,0], data_C4[:,1] - 3*data_C4[:,4], color = 'grey')
#plt.scatter(data_C3_100[:,0], (data_C3_100[:,1]-data_C3_100[:,2])/(data_C3_100[:,3]) , marker='x', label = '$m = 100$', color = 'green')



plt.xlabel("m", fontsize = 13)
plt.ylabel(r'$\frac{|\Delta|}{P.O.}$', rotation = 0, fontsize = 16)
plt.ticklabel_format(axis = 'both', scilimits = (0,3), useMathText = 'true')
plt.title("Deviazione relativa dai risultati delle simulazioni", fontsize = 15)
plt.legend()
plt.savefig('C_d3.png')
plt.show()

# %% [markdown]
# *In tutti i casi, plottimao il tempo necessario per eseguire una singola somma degli esponenziali dei due elementi (di a e di b)*

# %% [markdown]
# **Qui sotto, grafico 1: p_max=500;step=60;<<<1,256>>>; sovrapposto a p_max=500, step=150 e <<<4,1024>>>***
#
# *Si vede che aumetando il numero di thread e blocchi, la velocità aumenta e "ci sono meno gradini"*

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np


data_gpu1 = np.genfromtxt("./datagpu1.txt", delimiter = ',')
data_gpu14 = np.genfromtxt("./datagpu14.txt", delimiter = ',')
#plot data
plt.figure(figsize=(20,20))
plt.plot(data_gpu1[:,0], data_gpu1[:,1]/500, label='<<<1,256>>>')
plt.plot(data_gpu14[:,0], data_gpu14[:,1]/500, label='<<<4,1024>>>')
plt.xlabel("array length")
plt.ylabel(r' #$\mu$s for sum')
plt.legend(prop={'size': 20})
plt.show()

# %% [markdown]
# **Qui sotto, grafico 1.1 (GPU):per visualizzare meglio solo p_max=500;step=150; <<<4,1024>>>**

# %%
data_gpu14 = np.genfromtxt("./datagpu14.txt", delimiter = ',')

#plot data
plt.figure(figsize=(20,20))
plt.plot(data_gpu14[:,0], data_gpu14[:,1]/750, label='gpu')

plt.xlabel("array length")
plt.ylabel(r' #$\mu$ s for sum')
plt.legend(prop={'size': 20})
plt.show()

# %% [markdown]
# **Qui sotto, grafici 2 e 3: p_max=500 (gpu2),p_max=750 (gpu3);step=100 (gpu2), step=50 (gpu3);<<<1,1024>>>;**

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np


data_gpu2 = np.genfromtxt("./datagpu2.txt", delimiter = ',')
#plot data
plt.figure(figsize=(20,20))
plt.plot(data_gpu2[:,0], data_gpu2[:,1]/500, label='gpu, p=500')
plt.plot(data_gpu3[:,0], data_gpu3[:,1]/750, label='gpu, p=750')

plt.xlabel("array length")
plt.ylabel(r' #$\mu$s for 100 sum')
plt.legend(prop={'size': 20})
plt.show()

# %% [markdown]
# **Per semplicità, qui sotto, grafico 3 da solo: p_max=750;step=50;<<<1,1024>>>;**

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np


data_gpu3 = np.genfromtxt("./datagpu3.txt", delimiter = ',')

#plot data
plt.figure(figsize=(20,20))
plt.plot(data_gpu3[:,0], data_gpu3[:,1]/750, label='gpu')

plt.xlabel("array length")
plt.ylabel(r' #$\mu$ s for sum')
plt.legend(prop={'size': 20})
plt.show()

# %% [markdown]
# **Qui sotto, grafico 4: p_max=750;step=50;<<<32,1024>>>;kernel definito con while**
#
# *E' come il precedente, il numero di blocchi è aumentato a 32,più veloce, ancora gradini*

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np


data_gpu11 = np.genfromtxt("./datagpu11.txt", delimiter = ',')

#plot data
plt.figure(figsize=(20,20))
plt.plot(data_gpu11[:,0], data_gpu11[:,1]/750, label='gpu')

plt.xlabel("array length")
plt.ylabel(r' #$\mu$s for sum')
plt.legend(prop={'size': 20})
plt.show()

# %% [markdown]
# **Qui sotto, grafico 4.1 (GPU): p=750;step=120; <<<32,1024>>>. Rispetto a prima, è ristretto a lunghezze basse**
#
# *E' un accenno di grafico a scala*

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np



data_gpu12 = np.genfromtxt("./datagpu12.txt", delimiter = ',')
#plot data
plt.figure(figsize=(15,15))
plt.plot(data_gpu12[:,0], data_gpu12[:,1]/750, label='gpu3')
plt.xlabel("array length")
plt.ylabel(r' #$\mu$s for sum')
plt.legend(prop={'size': 15})
plt.show()

# %% [markdown]
# **Qui sotto, grafico 4.2 (GPU): p=5000;step=2000; <<<32,1024>>>**
#
# *Aumentato i cicli for*

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np


data_gpu13 = np.genfromtxt("./datagpu13.txt", delimiter = ',')

#plot data
plt.figure(figsize=(20,20))
plt.plot(data_gpu13[:,0], data_gpu13[:,1]/750, label='gpu')

plt.xlabel("array length")
plt.ylabel(r' #$\mu$ s for sum')
plt.legend(prop={'size': 20})
plt.show()

# %% [markdown]
# **Qui sotto, grafico 5: p=750;step=50;<<<grid_size, blcok_size>>>;kernel definito con if**
#
# *Non mostra andamento a gradini.Forse il passo dei gradini è maggiore di max_size, ma sembra lineare.Oppure è molto piccolo*

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np


data_gpu5 = np.genfromtxt("./datagpu5.txt", delimiter = ',')

#plot data
plt.figure(figsize=(20,20))
plt.plot(data_gpu5[:,0], data_gpu5[:,1]/750, label='gpu')

plt.xlabel("array length")
plt.ylabel(r' #$\mu$ s for sum')
plt.legend(prop={'size': 20})
plt.show()

# %% [markdown]
# **Qui sotto, grafico 8 (CPU): p=750;step=100; sovrapposto al grafico 3 (GPU) che utilizza gli stessi parametri**
#
# *Grandi fluttuazioni, però si può affermare che non è a scala.Più lento di un fattore~5*

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np


data_cpu1 = np.genfromtxt("./datacpu1.txt", delimiter = ',')
data_gpu3 = np.genfromtxt("./datagpu3.txt", delimiter = ',')
#plot data
plt.figure(figsize=(20,20))
plt.plot(data_cpu1[:,0], data_cpu1[:,1]/750, label='cpu')
plt.plot(data_gpu3[:,0], data_gpu3[:,1]/750, label='gpu3')
plt.xlabel("array length")
plt.ylabel(r' #$\mu$s for sum')
plt.legend(prop={'size': 15})
plt.show()

# %% [markdown]
# **Qui sotto, graficI 9, 10 E 11 (gPU): <<<grid_size,block_size>>> (come grafico 1); step = 150, p=500,2000,5000**

# %%
data_gpu15 = np.genfromtxt("./datagpu15.txt", delimiter = ',')
data_gpu16 = np.genfromtxt("./datagpu16.txt", delimiter = ',')
data_gpu17 = np.genfromtxt("./datagpu17.txt", delimiter = ',')
#plot data
plt.figure(figsize=(20,20))
plt.plot(data_gpu15[:,0], data_gpu15[:,1]/500, label='500 cicli')
plt.plot(data_gpu16[:,0], data_gpu16[:,1]/2000, label='2000 cicli')
plt.plot(data_gpu17[:,0], data_gpu17[:,1]/5000, label='5000 cicli')
plt.xlabel("array length")
plt.ylabel(r' #$\mu$s for sum')
plt.legend(prop={'size': 15})
plt.show()

# %% [markdown]
# **Qui sotto, grafico 12 (GPU): <<<16,1024>>>, step = 200, p=2000***

# %%
data_gpu18 = np.genfromtxt("./datagpu18.txt", delimiter = ',')
#plot data
plt.figure(figsize=(20,20))
plt.plot(data_gpu18[:,0], data_gpu18[:,1]/2000, label='gpu12')
plt.xlabel("array length")
plt.ylabel(r' #$\mu$s for sum')
plt.legend(prop={'size': 15})
plt.show()
